# %% [markdown]
# <a href="https://colab.research.google.com/github/tanmaysaxena18/GFG-21-days-Deep-Learning-Projects/blob/main/Netflix_Content_Strategy_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from wordcloud import WordCloud
sns.set_style('darkgrid')

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/GeeksforgeeksDS/21-Days-21-Projects-Dataset/main/Datasets/netflix_titles.csv'
netflix_df = pd.read_csv(url)
display(netflix_df.head())
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %%
netflix_df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
netflix_df.tail()
# Out:
#      show_id     type                                    title     director  \
# 7782   s7783    Movie                                     Zozo  Josef Fares
# 7783   s7784    Movie                                   Zubaan  Mozez Singh
# 7784   s7785    Movie                        Zulu Man in Japan          NaN
# 7785   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    cast  \
# 7782  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                                            Nasty C
# 7785                         Adriano Zumbo, Rachel Khoo
# 7786                                                NaN
#
#                                                 country          date_added  \
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
netflix_df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
netflix_df.describe()
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %% [markdown]
# S1 DATA CLEANING

# %%
netflix_df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
netflix_df.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
#netflix_df

# %%
#Filld miss vals
netflix_df['director']=netflix_df['director'].fillna('Unknown')
netflix_df['cast']=netflix_df['cast'].fillna('Unknown')
netflix_df['country']=netflix_df['country'].fillna('Unknown')

# %%
netflix_df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          7
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
netflix_df['country']
# Out:
# 0                                                  Brazil
# 1                                                  Mexico
# 2                                               Singapore
# 3                                           United States
# 4                                           United States
#                               ...
# 7782    Sweden, Czech Republic, United Kingdom, Denmar...
# 7783                                                India
# 7784                                              Unknown
# 7785                                            Australia
# 7786                United Kingdom, Canada, United States
# Name: country, Length: 7787, dtype: object

# %%
Mode_country = netflix_df['country'].mode()
Mode_country
# Out:
# 0    United States
# Name: country, dtype: object

# %%
netflix_df['country'] = netflix_df['country'].fillna(Mode_country)

# %%
netflix_df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
netflix_df.dropna(subset=['rating','date_added'], inplace=True)

# %%
netflix_df = netflix_df[netflix_df['date_added'] != 'Unknown'].copy()
netflix_df['date_added']=pd.to_datetime(netflix_df['date_added'],format='mixed',dayfirst=False)

# %%
netflix_df['year_added']=netflix_df['date_added'].dt.year

# %%
netflix_df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%            Unknown
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   date_added  release_year rating   duration  \
# 0 2020-08-14          2020  TV-MA  4 Seasons
# 1 2016-12-23          2016  TV-MA     93 min
# 2 2018-12-20          2011      R     78 min
# 3 2017-11-16          2009  PG-13     80 min
# 4 2020-01-01          2008  PG-13    123 min
#
# ...

# %%
netflix_df.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%            Unknown
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil 2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico 2016-12-23
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 1          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description  year_added  month_added
# 0  In a future where the elite inhabit an island ...        2020         2020
# 1  After a devastating earthquake hits Mexico Cit...        2016         2016

# %%
netflix_df['month_added']=netflix_df['date_added'].dt.year

# %% [markdown]
# S4 EDA

# %%
# Visualize the distribution of Movies vs. TV Shows
plt.figure(figsize=(8, 6))
type_counts = netflix_df['type'].value_counts()
sns.countplot(data=netflix_df, x='type', palette='viridis')
plt.title('Distribution of Movies vs. TV Shows on Netflix')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipython-input-4265455398.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=netflix_df, x='type', palette='viridis')

# %%
# Analyze content added over time
content_over_time = netflix_df['date_added'].dt.to_period('M').value_counts().sort_index()

plt.figure(figsize=(12, 6))
content_over_time.plot()
plt.title('Netflix Content Added Over Time (Monthly)')
plt.xlabel('Date Added')
plt.ylabel('Number of Titles Added')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
print(type_counts)
plt.pie(type_counts,labels=type_counts.index,autopct='%1.1f%%',startangle=140,colors=['#e60023','#221f1f'])
plt.axis('equal')
plt.title('Distribution of Movies vs. TV Shows on Netflix')
plt.show()
# Out:
# type
# Movie      5372
# TV Show    2398
# Name: count, dtype: int64

# %%
content_added_over_time=netflix_df.groupby(['year_added','type']).size().unstack().fillna(0)
content_added_over_time
# Out:
# type         Movie  TV Show
# year_added
# 2008           1.0      1.0
# 2009           2.0      0.0
# 2010           1.0      0.0
# 2011          13.0      0.0
# 2012           3.0      0.0
# 2013           6.0      5.0
# 2014          19.0      6.0
# 2015          58.0     30.0
# 2016         256.0    184.0
# 2017         861.0    361.0
# 2018        1255.0    429.0
# 2019        1497.0    656.0
# 2020        1312.0    697.0
# 2021          88.0     29.0

# %%
plt.figure(figsize=(14,8 ))
content_added_over_time.plot(kind='line', stacked=True)
plt.title('Content Added Over Time (Yearly)')
plt.xlabel('Year Added')
plt.ylabel('Number of Titles Added')
plt.legend(title='Type')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#pop genre

# %%
netflix_df.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%            Unknown
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil 2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico 2016-12-23
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
# 1          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description  year_added  month_added
# 0  In a future where the elite inhabit an island ...        2020         2020
# 1  After a devastating earthquake hits Mexico Cit...        2016         2016

# %%
genres=netflix_df.assign(genre=netflix_df['listed_in'].str.split(',')).explode('genre')

# %%
genres
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 0         s1  TV Show                                       3%
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 1         s2    Movie                                     7:19
# ...      ...      ...                                      ...
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0               Unknown  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
top_genres_count=genres['genre'].value_counts().reset_index()
top_genres_count.columns=['genre','count']

# %%
top_genres_count
# Out:
#                         genre  count
# 0        International Movies   2323
# 1                      Dramas   1383
# 2                    Comedies   1074
# 3               Documentaries    751
# 4                      Dramas    722
# ..                        ...    ...
# 68            Romantic Movies      3
# 69  Spanish-Language TV Shows      2
# 70              Sports Movies      1
# 71        TV Sci-Fi & Fantasy      1
# 72               LGBTQ Movies      1
#
# [73 rows x 2 columns]

# %%
top_15_genre=

# %%
#What is dist of cont dur

# %%
netflix_df.head(4)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%            Unknown
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#   date_added  release_year rating   duration  \
# 0 2020-08-14          2020  TV-MA  4 Seasons
# 1 2016-12-23          2016  TV-MA     93 min
# 2 2018-12-20          2011      R     78 min
# 3 2017-11-16          2009  PG-13     80 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# ...

# %%
movies_df=netflix_df[netflix_df['type']=='Movie'].copy()
tv_show_df=netflix_df[netflix_df['type']=='TV Show'].copy()

# %%
tv_show_df
# Out:
#      show_id     type                  title              director  \
# 0         s1  TV Show                     3%               Unknown
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983               Unknown
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09               Unknown
# ...      ...      ...                    ...                   ...
# 7767   s7768  TV Show     Zindagi Gulzar Hai               Unknown
# 7775   s7776  TV Show             Zoids Wild               Unknown
# 7777   s7778  TV Show            Zombie Dumb               Unknown
# 7779   s7780  TV Show              Zona Rosa               Unknown
# 7785   s7786  TV Show  Zumbo's Just Desserts               Unknown
#
#                                                    cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#Clean and convert dur for movies
movies_df['duration']=movies_df['duration'].str.replace(' min','').astype(int)
movies_df['duration']=movies_df['duration'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2294155162.py in <cell line: 0>()
#       1 #Clean and convert dur for movies
# ----> 2 movies_df['duration']=movies_df['duration'].str.replace(' min','').astype(int)
#       3 movies_df['duration']=movies_df['duration'].astype(int)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
# ...

# %%
movies_df

# %%
tv_show_df['seasons']=tv_show_df

# %%
fig,axes=plt.subplots(1,2,figsize=(18,7))
sns.

# %% [markdown]
# #where does most contain come from

# %%
countries=netflix_df.assign(country=netflix_df['country'].str.split(',')).explode('country')

# %%
countries
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0               Unknown  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#incorr
plt.figure(figsize=(14, 7))
sns.lineplot(data=top_15_countries, x='country', y='count')
plt.title('Top 15 Countries with Most Content on Netflix')
plt.xlabel('Country')
plt.ylabel('Number of Titles')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
top_15_countries = countries['country'].value_counts().head(15).reset_index()
top_15_countries.columns=['country','count']

# %%
# Separate movies and TV shows
movies_df = netflix_df[netflix_df['type'] == 'Movie'].copy()
tv_show_df = netflix_df[netflix_df['type'] == 'TV Show'].copy()

# %%
# Clean and convert duration for movies
movies_df['duration'] = movies_df['duration'].str.replace(' min', '').astype(int)
display(movies_df.head())
# Out:
#   show_id   type  title           director  \
# 1      s2  Movie   7:19  Jorge Michel Grau
# 2      s3  Movie  23:59       Gilbert Chan
# 3      s4  Movie      9        Shane Acker
# 4      s5  Movie     21     Robert Luketic
# 6      s7  Movie    122    Yasir Al Yasiri
#
#                                                 cast        country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 6  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
#
#   date_added  release_year rating  duration  \
# 1 2016-12-23          2016  TV-MA        93
# 2 2018-12-20          2011      R        78
# 3 2017-11-16          2009  PG-13        80
# 4 2020-01-01          2008  PG-13       123
# 6 2020-06-01          2019  TV-MA        95
#
# ...

# %%
# Clean and convert duration for TV shows
tv_show_df['duration'] = tv_show_df['duration'].str.replace(' Season(s)?', '', regex=True).str.strip().astype(int)
display(tv_show_df.head())

# %% [markdown]
# Feature engineering

# %%
netflix_df['age_on_netflix'] = netflix_df['year_added'] - netflix_df['release_year']

# %%
content_age=netflix_df

# %% [markdown]
# Deeper Multivar Analysis

# %%
top_genres=genres['genre'].value_counts().index[:5]
genres_movies=genres[(genres['type']=='Movie')&(genres['genre'].isin(top_genres))].copy()

# %%
genres_movies

# %% [markdown]
# Wordcloud

# %%
txt=' '.join(netflix_df['description'])
txt
# Out:
# 'In a future where the elite inhabit an island paradise far from the crowded slums, you get one chance to join the 3% saved from squalor. After a devastating earthquake hits Mexico City, trapped survivors from all walks of life wait to be rescued while trying desperately to stay alive. When an army recruit is found dead, his fellow soldiers are forced to confront a terrifying secret that\'s haunting their jungle island training camp. In a postapocalyptic world, rag-doll robots hide in fear from dangerous machines out to exterminate them, until a brave newcomer joins the group. A brilliant group of students become card-counting experts with the intent of swindling millions out of Las Vegas casinos by playing blackjack. A genetics professor experiments with a treatment for his comatose sister that blends medical and shamanic cures, but unlocks a shocking side effect. After an awful accident, a couple admitted to a grisly hospital are separated and must find each other to escape — befor
# ...

# %%
wordcloud=wordcloud(width=800,height=400,background_color='white').generate(txt)
plt.figure(figsize=(10,5))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()
